# %%
import joblib

# %%
model = joblib.load('LogisticRegression_model.pkl')

# %%
prediction = model.predict([[1,2,3,4,5,6,7,8]])
# Out:
# D:\Anaconda\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
print(prediction)
# Out:
# [0]
